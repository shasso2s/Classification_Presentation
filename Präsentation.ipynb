# %% [markdown]
# <div style="text-align:center;serif: times, serif; font-size:25pt; font-style:italic"> Klassifizierung</div>
#
#
# ##   Inhaltsverzeichnis:
#
# ###  Binäre klassifizierung
#
# 1. *FallBespiel*
#     1. Interpretaion
# 2. *Definition*
# 3. *Verwendungszweck*
#
#
# ###   Metriken für Klassifizierungsmodelle
#
# 1. **Die Confusion-Matrix**
#     1. *Accuracy*
#     2. *Recall- Sensitivity*
#     3. *Precision*
#     4. *Specify*
#     5. Receiver operating characteristic Kurve
#         1. *Schwellwert-Threshold*
#         2. *ROC*
#         3. *Area Under the Curve*
#
# ###   Feature Selection
# 1. *Definition*
# 2. *Verwendungszweck*
# 3. *Vorgehensweise*
#   1. *Filter methoden*
#     1. *Pearson correlation*
#     2. *Mutula Information*
#     3. *f_classif*

# %% [markdown]
# ### Binäre Klassifizierung
#
# ####  1.  FallBespiell
# <img src= kj.PNG></h3>
#
# ##### A. Interpretation
# <p style="serif: times, serif; font-size:12pt">
# Die Ergebnisse der Krankenakte weisen darauf hin, dass einige Patienten mit bekannten Krankheiten
# <b>Features</b>am Herzinfarkt leiden können, während das Fehlen dieser Krankheiten in einer anderen Kategorie auf ihren Gesundheitszustand hinweisen kann. Dem zufolge können wir die Auswertung in zwei Gruppen <b>Cluster</b> kategorisieren::
# </p>
# <p style="serif: times, serif; font-size:12pt">
#             Positive  ❤️‍🩹
# </p>
# <p style="serif: times, serif; font-size:12pt">
#             Negative  💗
# </p>
# <p style="serif: times, serif; font-size:12pt">
#  In machine learning Sprache bezeicht die :
# </p>
# <p style="serif: times, serif; font-size:12pt">
#     ❤️‍🩹 <font color = 'red'>    class label   1
# </p>
# <p style="serif: times, serif; font-size:12pt">
#     ❤️‍ <font color = 'green '> class label 0
# </p>

# %% [markdown]
# #### 2. Definition :
#
# <p style="serif: times, serif; font-size:12pt">
#     Bei der Binäre Klassifizierung geht es darum  die Elemente einer Menge auf der Grundlage einer Klassifizierungsregel in zwei Gruppen einzuteilen
# </p>
#
# #### 3. Verwendungszweck
#
# <p style="serif: times, serif; font-size:12pt">
# Die binäre Klassifizierung ist die Aufgabe , die Elemente einer Menge auf der Grundlage einer Klassifizierungsregel in zwei
# Gruppen zu klassifizieren . Typische Probleme bei der binären Klassifizierung sind:
# </p>
#
# <p style="serif: times, serif; font-size:12pt">
# 1. Medizinische Tests : um festzustellen, ob ein Patient eine bestimmte Krankheit hat oder nicht.
#  </p>
#
# <p style="serif: times, serif; font-size:12pt">
# 2. Qualitätskontrolle : in der Industrie, Entscheidung, ob eine Spezifikation erfüllt wurde.
# </p>

# %% [markdown]
# ###  Metriken für Klassifizierungsmodelle
#
# #### 1. Die Confusion-Matrix
#
# <p style="serif: times, serif; font-size:12pt">
# Die Confusion-Matrix ist ein Leistungsmaß für die Klassifizierung beim maschinellen Lernen, um der Confusion matrix besser zu vesthen, schauen wir uns das folgende Beispiel an .
# </p>
#
# <img src= cfb.PNG></h3>

# %% [markdown]
# <p style="serif: times, serif; font-size:12pt; font-style:italic">
# <b>True Positive:</b> Die Vorhersage lautet dass,  eine Frau schwanger ist, und sie ist es .
# </p>
# <p style="serif: times, serif; font-size:12pt; font-style:italic">
# <b>True Negative:</b> Die Vorhersage lautet dass, ein Mann nicht schwanger ist, und er ist es  nicht.</p>
# <p style="serif: times, serif; font-size:12pt; font-style:italic">
# <b>False positive:</b> Die Vorhersage lautet dass, ein Mann schwanger ist, aber er ist es  nicht.</p>
# <p style="serif: times, serif; font-size:12pt; font-style:italic">
# <b>False Negative:</b> Die Vorhersage lautet dass, eine Frau nicht schwanger ist, aber sie ist es </p>

# %% [markdown]
# <p><h3 style ="color:tomato"> Welche Informationen lassen sich von der Confusion-Matrix ableiten?</p> </h3>

# %% [markdown]
# #####  A. Accuracy:
# <p style="serif: times, serif; font-size:12pt">
# Ist der Anteil der richtigen Ergebnisse an der Gesamtzahl der untersuchten Fälle.
# </p>
#
# <p><div style="text-align:center; font-size:12pt;">      Accuracy=(TP+TN)/(TP+FP+FN+TN)</p></div>
#
# ##### B. Recall-Sensitivity :
# <p style="serif: times, serif; font-size:12pt">
# Er gibt der Anteil der Objekte der positiven klasse an, den wir mit unserem Modell erwischen bzw detektieren.
# </p>
#
# <p><div style="text-align:center; font-size:12pt;">Recall = TP/(TP+FN)</p></div>
#
#
# ##### C. Precision :
# <p style="serif: times, serif; font-size:12pt">
# Beatworet die Frage , welcher Anteil der vorhergesagten positiven ist wirklich postive.
# </p>
# <p><div style="text-align:center; font-size:12pt;">Precision = TP/(TP+FP)</p></div>
#
#
#
# ##### D. Specify
# <p style="serif: times, serif; font-size:12pt">
# Bentwortet die Frage , welcher Anteil der vorhergesagten negativen ist wirklich negative.
# </p>
# <p><div style="text-align:center; font-size:12pt;">Specify= TN/(TN+FP)</p></div>

# %% [markdown]
# ##### E. Receiver operating characteristic Kurve
#
# ###### a. Schwellwert-Threshold
# <p style="serif: times, serif; font-size:12pt">
# Ohne Veränderung der Daten oder des Modells kann man nicht Precision  und Recall Gleichmaßen verbessern, bei vielen Modellen gibt  es jedoch einen sog.<b>Threshold-Parameter</b>  mit dem wir zum Beispiel die Precision verbessern können, jedoch dadurch den Recall verschlechtern.
# </p>
#
#
#
# <img src= lo.PNG></h3>

# %% [markdown]
# ###### b. Der Receiver Operator Charateristic:
#
# <p style="serif: times, serif; font-size:12pt">
# Der Receiver Operator Charateristic (ROC) Kurve ist eine weitere häufig verwendete Metrik, in dem wir zunächst die True Positive Rate( Recall oder Sensitivity) und False Positive Rate  für verschiedene Thresholds. Anschließend bekommt man eine Kurve(sehe die rechte Abbildung).
# </p>
#
# <p style="serif: times, serif; font-size:12pt">
# Nehmen wir als beispiel dass, die Threshold unter allen punkten in der Abbildung liegt das heißt:
# </p>
# <p>
# <b><center>TP =n , TN =0, FN =0, Fp =0</p></b></center>
#
# <p style="serif: times, serif; font-size:12pt">
# Daraus  kommt das Ergebnis :
# <b><center>Sensitivity =1 und  FPR=1-Specifity=1-0=1</b></center>
# </p>
#
#
# <p style="serif: times, serif; font-size:12pt">
# Der punkt (1,1) in Der Abbildung  bedeutet dass:
# <b><center>True positive Rate= False Positive Rate </b></center>
# </p>
#
# <p style="serif: times, serif; font-size:12pt">
# Hinterher nehmen wir eine andere threshold und rechnen wir sensitivity (TPR) und FPR (1-specifity).Anschliessend bekommen wir die rechte Abbildung.
# </p>
#
#
# ###### c. AUC-Score
# <p style="serif: times, serif; font-size:12pt">
# Die Fläche unter dieser Kurve ist der <b>AUC-Score (Area Under the Curve)</b>.  Ein optimaler Classifier ergibt einen Wert von 1, ein Classifier der nicht besser ist als der Zufall ergibt einen Wert von 0.5.
#
#
# <h3 style ="color:tomato">Was ist das beste Threshold?</h3>
#
#
# <p style="serif: times, serif; font-size:12pt">
# Der Auswahl von Threshold hängt von  Daten und Zweck ab. Bei Spam filter ist TPR sehr wichtig, denn es ist nicht gut wichtige Mail als Spam zu klassifizieren, anders fall bei kindersicherung ist es nicht schlimm filme von klasse 0 als klasse 1 zu strukturieren.
# </p>

# %% [markdown]
# ### Feature Selection
#
# #### 1. Definition:
# <p style="serif: times, serif; font-size:12pt">
# Ist der Prozess von  Reduzierung der Anzahl der Input variable <b>Features</b> bei der Entwicklung eines Vorhersagemodells.
# </p>
#
#
# #### 2. Verwendungszweck:
# <p style="serif: times, serif; font-size:12pt">
#
# 1. Reduzierung des hohen Rechenaufwands
# 2. Verringerung der Speicherkapazität
# 3. Erhöhen die Performance des Modells
# </p>
#
#
# #### 3. Vorgehensweise
# <p style="serif: times, serif; font-size:12pt">
# Bei den statistischen Verfahren zum Feature Selektion wird die Beziehung zwischen dem Input variable und Output variable <b>Target variable</b> mithilfe von Statistiken bewertet, und es werden die Inputs variable selektiert die stärkste Beziehung zum Target variable aufweisen.
# </p>
#
#
#
# <h3 style ="color:tomato"> Woran erkenne ich, ob die Beziehung stark ist oder nicht?
# </h3>

# %% [markdown]
# #####  1. Die Filter-Methoden :
#
# ###### a. Pearson correlation:
# <p style="serif: times, serif; font-size:12pt">
# Die Pearson-Korrelation ist ein Maß dafür, wie stark zwei Zufallsvariablen X und Y linear korreliert sind. Sie wird als Zahl zwischen -1 und 1 angegeben. Wir können die Pearson-Korrelation zwischen Eingangsmerkmalen und Modellergebnissen zur Auswahl von Merkmalen verwenden. Dies funktioniert besonders gut bei linearen Regressionsproblemen. Der Pearson-Koeffizient wird wie folgt berechnet.
# </p>
# <p>
#     <center><b> r  =   n*∑(XY)-∑(X)*∑(Y)/sqrt[n*∑(x**2)-(∑(x)**2)][n*∑(y**2)-(∑(y))**2</p></center></b>
#
#
#
#
# ###### b. Mutual Information:
# <p style="serif: times, serif; font-size:12pt">
# Ein Proxy, der verwendet werden kann, ist die mutual Information zwischen input variable und den output variable. Die mutual  Information ist in diesem Fall ein Maß dafür, wie viele nützliche Informationen durch die Einbeziehung eines bestimmten Merkmals an das Modell weitergegeben werden. Daher kann die Einbeziehung von Merkmalen mit hoher gegenseitiger Information hilfreich sein, um die Modellgenauigkeit zu erhöhen.Die Mutual information wird wie folgt berechnet.
# </p>
#
# <p>
# <center><b>  I(X,Y)  =  ∑ ∑ P(x1,x2).log P(x1,x2)/P(x1)*P(x2) </p>   </center></b>
#
# ###### c. f_classif:
# <p style="serif: times, serif; font-size:12pt">
# Basiert auf dem ANOVA-Test, einem parametrischen statistischen Hypothesentest, mit dem festgestellt werden kann, ob die Mittelwerte von zwei oder mehr Datenstichproben (oft drei oder mehr) aus der gleichen Verteilung stammen oder nicht.
# </p>
